# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from skimage.io import imread, imshow

# %%
img=imread('img/chest_xray_1.png')
imshow(img)
# Out:
# C:\Users\Guillaume Demets\AppData\Local\Temp\ipykernel_1688\1978774771.py:3: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(img)
